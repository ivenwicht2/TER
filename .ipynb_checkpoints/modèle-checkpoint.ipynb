# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
AUTOTUNE = tf.data.experimental.AUTOTUNE
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
import pathlib

data_dir = pathlib.Path("DATA")

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 65

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"])
CLASS_NAMES
# Out:
# array(['D46D', 'F35', 'F36'], dtype='<U4')

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)

# %%
train_data_gen = image_generator.flow_from_directory(directory=str(data_dir),
                                                     batch_size=BATCH_SIZE,
                                                     shuffle=True,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                     classes = list(CLASS_NAMES))
# Out:
# Found 65 images belonging to 3 classes.

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
      plt.axis('off')

# %%
image_batch, label_batch = next(train_data_gen)
show_batch(image_batch, label_batch)

# %%
label = []
for item in label_batch:
    label.append(np.argmax(item))
label = np.array(label)

# %%
from sklearn.model_selection import train_test_split

(trainX, testX, trainY, testY) = train_test_split(image_batch, label, test_size=0.25)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(13, activation='softmax'))

# %%
type(testY)
# Out:
# numpy.ndarray

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(trainX, trainY, epochs=12, 
                    validation_data=(testX, testY))
# Out:
# Train on 24 samples, validate on 8 samples
# Epoch 1/12
# 24/24 [==============================] - 2s 86ms/sample - loss: 2.5310 - accuracy: 0.0833 - val_loss: 3.5445 - val_accuracy: 0.7500
# Epoch 2/12
# 24/24 [==============================] - 1s 62ms/sample - loss: 7.5050 - accuracy: 0.4167 - val_loss: 7.1106 - val_accuracy: 0.1250
# Epoch 3/12
# 24/24 [==============================] - 1s 49ms/sample - loss: 4.4540 - accuracy: 0.3750 - val_loss: 3.3802 - val_accuracy: 0.1250
# Epoch 4/12
# 24/24 [==============================] - 1s 46ms/sample - loss: 2.5571 - accuracy: 0.2083 - val_loss: 0.6876 - val_accuracy: 0.7500
# Epoch 5/12
# 24/24 [==============================] - 1s 46ms/sample - loss: 1.0509 - accuracy: 0.4167 - val_loss: 1.1176 - val_accuracy: 0.5000
# Epoch 6/12
# 24/24 [==============================] - 1s 46ms/sample - loss: 1.1020 - accuracy: 0.6667 - val_loss: 1.0378 - val_accuracy: 0.5000
# Epoch 7/12
# 24/24 [==============================] - 1s 45ms/sample - loss: 1.0266 - accuracy: 0.7500 - val_loss: 0.6750 - val_accuracy: 0.7500
# Epoch 8/12
# 24/24 [==============================] - 1s 45ms/sample - loss: 0.8502 - accuracy: 0.4167 - val_loss: 1.3318 - val_accuracy: 0.1250
# Epoch 9/12
# 24/24 [==============================] - 1s 50ms/sample - loss: 0.7824 - accuracy: 0.7500 - val_loss: 0.8717 - val_accuracy: 0.5000
# Epoch 10/12
# 24/24 [==============================] - 1s 53ms/sample - loss: 0.5066 - accuracy: 1.0000 - val_loss: 0.6772 - val_accuracy: 0.7500
# Epoch 11/12
# 24/24 [==============================] - 1s 52ms/sample - loss: 0.7922 - accuracy: 0.5000 - val_loss: 2.0146 - val_accuracy: 0.1250
# Epoch 12/12
# 24/24 [==============================] - 1s 52ms/sample - loss: 0.7459 - accuracy: 0.5833 - val_loss: 1.4219 - val_accuracy: 0.1250

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(testX,  testY, verbose=2)
# Out:
# 8/1 - 0s - loss: 1.4219 - accuracy: 0.1250

# %%
print(test_acc)
# Out:
# 0.125
